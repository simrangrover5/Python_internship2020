# %% [markdown]
# #### Flipcart Scraping

# %%
import requests
url = "https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&as-backfill=on"

# %%
page = requests.get(url)

# %%
page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(page.content,'html')

# %%
data
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.66c84c.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
names = []
for i in data.find_all("div",attrs={"class":"_3wU53n"}):
    print(i.text)
    names.append(i.text)
# Out:
# HP 15q Core i3 8th Gen - (4 GB/1 TB HDD/Windows 10 Home) 15q-ds0058TU Thin and Light Laptop
# Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412FA-EK361T Thin and Light Lap...
# Lenovo Ideapad S145 Core i3 8th Gen - (4 GB/1 TB HDD/DOS) S145-15IKB Laptop
# HP 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) 15-db1069AU Laptop
# Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466
# HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX...
# HP Pavilion x360 Core i3 8th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14-dh0107TU 2 in 1 Laptop
# Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) UX430UA-GV573T Thin and Light Laptop
# Asus VivoBook S Series Core i5 8th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) S430FA-EB039T Thin...
# Asus VivoBook 15 Core i5 8th Gen - (8 GB/1 TB HDD/Windows 10 Home/2 GB Graphics) X543UB-DM581T Laptop
# ...

# %%
ratings = []
for i in data.find_all("div",attrs={"class":"hGSR34"}):
    print(i.text)
    ratings.append(i.text)
# Out:
# 4
# 4.5
# 4.1
# 4.1
# 4.7
# 4.4
# 4.5
# 4.3
# 4.5
# 4.1
# 4.3
# 4.5
# 4.2
# 4.2
# 4.8
# 4.1
# 4
# 3.8
# 4
# 4.1
# 4.5
# 4.5
# 4.4
# 4.1
# 5
# 4
# 4.4
# 5
# 5
# 4.5
# 5
# 5
# 4
# 4
# 4
# 4.1
# 4
# 1

# %%
dis_price = []
for i in data.find_all("div",attrs={"class":"_1vC4OE _2rQ-NK"}):
    print(i.text)
    dis_price.append(i.text)
# Out:
# ₹31,990
# ₹35,990
# ₹28,990
# ₹27,990
# ₹71,990
# ₹54,990
# ₹44,990
# ₹45,990
# ₹49,990
# ₹44,760
# ₹30,990
# ₹35,990
# ₹37,990
# ₹37,990
# ₹41,990
# ₹44,760
# ₹19,990
# ₹38,990
# ₹29,990
# ₹36,990
# ₹51,990
# ₹52,990
# ₹49,990
# ₹56,990

# %%
actual_price = []
for i in data.find_all("div",attrs={"class":"_3auQ3N _2GcJzG"}):
    print(i.text)
    actual_price.append(i.text)
# Out:
# ₹35,360
# ₹44,990
# ₹35,990
# ₹31,555
# ₹84,900
# ₹56,145
# ₹48,240
# ₹86,990
# ₹68,990
# ₹45,730
# ₹35,060
# ₹38,111
# ₹43,790
# ₹43,790
# ₹58,690
# ₹45,730
# ₹22,392
# ₹40,788
# ₹33,040
# ₹39,790
# ₹68,900
# ₹62,589
# ₹55,591
# ₹74,990

# %%
len(ratings)
# Out:
# 38

# %%
len(actual_price)
# Out:
# 24

# %%
len(dis_price)
# Out:
# 24

# %%
len(names)
# Out:
# 24

# %%
list(zip(ratings,names))
# Out:
# [('4',
#   'HP 15q Core i3 8th Gen - (4 GB/1 TB HDD/Windows 10 Home) 15q-ds0058TU Thin and Light Laptop'),
#  ('4.5',
#   'Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412FA-EK361T Thin and Light Lap...'),
#  ('4.1',
#   'Lenovo Ideapad S145 Core i3 8th Gen - (4 GB/1 TB HDD/DOS) S145-15IKB Laptop'),
#  ('4.1',
#   'HP 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) 15-db1069AU Laptop'),
#  ('4.7',
#   'Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466'),
#  ('4.4',
#   'HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX...'),
#  ('4.5',
#   'HP Pavilion x360 Core i3 8th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14-dh0107TU 2 in 1 Laptop'),
#  ('4.3',
#   'Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) UX430UA-GV573T Thin and Light Laptop'),
#  ('4.5',
# ...

# %%
def get_product_details(product):
    url = f"https://www.flipkart.com/search?q={product}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&as-backfill=on"
    page = requests.get(url)
    if page.status_code == 200:
        data = BeautifulSoup(page.content,'html')
        names = []
        for i in data.find_all("div",attrs={"class":"_3wU53n"}):
            names.append(i.text)
        ratings = []
        for i in data.find_all("div",attrs={"class":"hGSR34"}):
            ratings.append(i.text)
        dis_price = []
        for i in data.find_all("div",attrs={"class":"_1vC4OE _2rQ-NK"}):
            dis_price.append(i.text)
        actual_price = []
        for i in data.find_all("div",attrs={"class":"_3auQ3N _2GcJzG"}):
            actual_price.append(i.text)
        for n,r,d,a in zip(names,ratings,dis_price,actual_price):
            print("*"*80)
            print(f"Name : {n}".center(80))
            print(f"Rating : {r}".center(80))
            print(f"After Discount Price : {d}".center(80))
            print(f"Actual Price : {d}".center(80))
            print("*"*80)
    else:
        return "Invalid Url"
    
product = input("\n Enter product : ")
get_product_details(product)
# Out:
#  Enter product : oppo A9
# ********************************************************************************
#                    Name : OPPO A9 2020 (Marine Green, 128 GB)
#                                   Rating : 4.4
#                          After Discount Price : ₹13,990
#                              Actual Price : ₹13,990
# ********************************************************************************
# ********************************************************************************
#                    Name : OPPO A9 2020 (Vanilla Mint, 128 GB)
#                                   Rating : 4.4
#                          After Discount Price : ₹13,990
#                              Actual Price : ₹13,990
# ********************************************************************************
# ********************************************************************************
#                    Name : OPPO A9 2020 (Space Purple, 128 GB)
# ...

# %%
for i in data.find_all("div",attrs={"class":"col col-7-12"}):
    print(i)
# Out:
# <div class="col col-7-12"><div class="_3wU53n">HP 15q Core i3 8th Gen - (4 GB/1 TB HDD/Windows 10 Home) 15q-ds0058TU Thin and Light Laptop</div><div class="niH0FQ"><span class="_2_KrJI" id="productRating_LSTCOMFQYHMGHVZDZAZEYVJTL_COMFQYHMGHVZDZAZ_"><div class="hGSR34">4<img class="_2lQ_WZ" src="..."/></div></span><span class="_38sUEc"><span><span>144 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 22 Reviews</span></span></span></div><div class="_3ULzGw"><ul class="vFw0gD"><li class="tVe95H">Intel Core i3 Processor (8th Gen)</li><li class="tVe95H">4 GB DDR4 RAM</li><li class="tVe95H">64 bit Windows 10 Operating System</li><li class="tVe95H">1 TB HDD</li><li class="tVe95H">39.62 cm (15.6 inch) Display</li><li class="tVe95H">1 Year Onsite Warranty</li></ul></div></div>
# ...

# %%
names = []
ratings = []
for i in data.find_all("div",attrs={"class":"col col-7-12"}):
    names.append(i.select("._3wU53n")[0].text)
    try:
        ratings.append(i.select(".hGSR34")[0].text)
    except:
        ratings.append(None)

# %%
names
# Out:
# ['HP 15q Core i3 8th Gen - (4 GB/1 TB HDD/Windows 10 Home) 15q-ds0058TU Thin and Light Laptop',
#  'Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 GB SSD/Windows 10 Home) X412FA-EK361T Thin and Light Lap...',
#  'Lenovo Ideapad S145 Core i3 8th Gen - (4 GB/1 TB HDD/DOS) S145-15IKB Laptop',
#  'HP 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windows 10 Home) 15-db1069AU Laptop',
#  'Apple MacBook Air Core i5 5th Gen - (8 GB/128 GB SSD/Mac OS Sierra) MQD32HN/A A1466',
#  'HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1 TB HDD/Windows 10 Home/4 GB Graphics/NVIDIA Geforce GTX...',
#  'HP Pavilion x360 Core i3 8th Gen - (4 GB/256 GB SSD/Windows 10 Home) 14-dh0107TU 2 in 1 Laptop',
#  'Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SSD/Windows 10 Home) UX430UA-GV573T Thin and Light Laptop',
#  'Asus VivoBook S Series Core i5 8th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) S430FA-EB039T Thin...',
# ...

# %%
ratings
# Out:
# ['4',
#  '4.5',
#  '4.1',
#  '4.1',
#  '4.7',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.5',
#  '4.1',
#  '4.3',
#  '4.5',
#  '4.2',
#  '4.2',
#  '4.8',
#  '4.1',
#  '4',
#  '3.8',
#  '4',
#  '4.1',
#  '4.5',
#  '4.5',
#  '4.4',
#  None]

# %%
import requests
from bs4 import BeautifulSoup
def get_product_details(product):
    url = f"https://www.flipkart.com/search?q={product}&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off&as-pos=1&as-type=HISTORY&as-backfill=on"
    page = requests.get(url)
    if page.status_code == 200:
        data = BeautifulSoup(page.content,'html')
        names = []
        ratings = []
        for i in data.find_all("div",attrs={"class":"col col-7-12"}):
            names.append(i.select("._3wU53n")[0].text)
            try:
                ratings.append(i.select(".hGSR34")[0].text)
            except:
                ratings.append(None)
        dis_price = []
        for i in data.find_all("div",attrs={"class":"_1vC4OE _2rQ-NK"}):
            dis_price.append(i.text)
        actual_price = []
        for i in data.find_all("div",attrs={"class":"_3auQ3N _2GcJzG"}):
            actual_price.append(i.text)
        for n,r,d,a in zip(names,ratings,dis_price,actual_price):
            print("*"*80)
            print(f"Name : {n}".center(80))
            print(f"Rating : {r}".center(80))
            print(f"After Discount Price : {d}".center(80))
            print(f"Actual Price : {a}".center(80))
            print("*"*80)
    else:
        return "Invalid Url"
    
product = input("\n Enter product : ")
get_product_details(product)
# Out:
#  Enter product : oppo
# ********************************************************************************
#                     Name : OPPO A31 (Fantasy White, 128 GB)
#                                   Rating : 4.3
#                          After Discount Price : ₹14,990
#                              Actual Price : ₹15,990
# ********************************************************************************
# ********************************************************************************
#                     Name : OPPO A31 (Mystery Black, 128 GB)
#                                   Rating : 4.3
#                          After Discount Price : ₹14,990
#                              Actual Price : ₹15,990
# ********************************************************************************
# ********************************************************************************
#                      Name : OPPO A31 (Mystery Black, 64 GB)
#                                   Rating : 4.3
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame({"Names":names,"Ratings":ratings,"Actual Price":actual_price,"Discount Price":dis_price})

# %%
df
# Out:
#                                                 Names Ratings Actual Price  \
# 0   HP 15q Core i3 8th Gen - (4 GB/1 TB HDD/Window...       4      ₹35,360
# 1   Asus VivoBook 14 Core i3 10th Gen - (4 GB/256 ...     4.5      ₹44,990
# 2   Lenovo Ideapad S145 Core i3 8th Gen - (4 GB/1 ...     4.1      ₹35,990
# 3   HP 15 Ryzen 3 Dual Core - (4 GB/1 TB HDD/Windo...     4.1      ₹31,555
# 4   Apple MacBook Air Core i5 5th Gen - (8 GB/128 ...     4.7      ₹84,900
# 5   HP Pavilion Gaming Ryzen 5 Quad Core - (8 GB/1...     4.4      ₹56,145
# 6   HP Pavilion x360 Core i3 8th Gen - (4 GB/256 G...     4.5      ₹48,240
# 7   Asus ZenBook Core i5 8th Gen - (8 GB/256 GB SS...     4.3      ₹86,990
# 8   Asus VivoBook S Series Core i5 8th Gen - (8 GB...     4.5      ₹68,990
# 9   Asus VivoBook 15 Core i5 8th Gen - (8 GB/1 TB ...     4.1      ₹45,730
# 10  Asus VivoBook 15 Core i3 8th Gen - (4 GB/256 G...     4.3      ₹35,060
# ...

# %%
df['Ratings'].value_counts().plot(kind='bar')

# %% [markdown]
# ##### amazon site scrap
# ##### try to scrap 2-3 more websites to get some useful data
