# %% [markdown]
# ### Joins
#
#     1. inner (intersection)
#     2. outer (union)
#     3. left
#         student join fees
#             It will give all data of student table but the common data of fees and student table
#     4. right
#         student and fees
#             It will give all data of fees and common data of both the tables

# %% [markdown]
#     s1 = {1,2,3,4}
#     s2 = {1,2}
#     inter = {1,2}

# %% [markdown]
#     student                   fees
#        name                    fid
#        course                 fees
#        address                 sid
#        id                     discount
#                               disposit
#
#       id = {101,102,103,104,105,106,107,108}
#       sid1 = {101,102,103,104,107}
#       inter = {101,102,103,104,107}
#       sid2 = {102,104,105,107}
#       intersection of id,sid1,sid2 is
#       {102,107}
#       (id = sid1) and (id=sid2)
#       {101,102,103,104,107} and {102,104,105,107}
#       {102,104,107}

# %%
from PIL import Image

# %%
Image.open("eah_sql_blog1.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x600 at 0x22A6CABAC08>

# %%
import sqlalchemy

# %% [markdown]
# ###### pip install sqlalchemy
# ##### pip install ipython-sql
# ##### pip install Flask-MySQLdb

# %%
#ipython--> ipython --> interactive python shell

# %%
### pip install --> pypi.org

# %%
import sqlalchemy

# %%
sqlalchemy.create_engine("mysql://root:@localhost/internship_batch")   #db_server://username:@hostname/db_name
# Out:
# Engine(mysql://root:***@localhost/internship_batch)

# %%
# %load_ext sql

# %%
# %sql mysql://root:@localhost/internship_batch

# %%
# %%sql
# select * from student;
# Out:
#  * mysql://root:***@localhost/internship_batch
# 8 rows affected.
# [(101, 'shivani', 'ds', 'female'),
#  (102, 'rohan', 'ml', 'male'),
#  (103, 'anisha', 'aws', 'female'),
#  (104, 'anushka', 'aws', 'female'),
#  (105, 'devraj', 'cloud', 'male'),
#  (106, 'koashal', 'python', 'male'),
#  (107, 'priyanka', 'python', 'female'),
#  (108, 'naresh', 'ds', 'male')]

# %%
# %%sql
# select * from fees;
# Out:
#  * mysql://root:***@localhost/internship_batch
# 6 rows affected.
# [(1, 101, 12000.0, 2000.0, 10000.0),
#  (2, 102, 13000.0, 1200.0, 11000.0),
#  (3, 103, 15000.0, 2500.0, 9000.0),
#  (4, 104, 15000.0, 1300.0, 9000.0),
#  (5, 107, 25000.0, 2500.0, 19000.0),
#  (6, 105, 22000.0, 6000.0, 15000.0)]

# %%
# %%sql
# select * from address where city="jaipur";
# Out:
#  * mysql://root:***@localhost/internship_batch
# 2 rows affected.
# [(1, 101, 'jaipur', 'raja park'), (2, 102, 'jaipur', 'malviya nagar')]

# %%
import matplotlib.pyplot as plt

# %%
data = %sql select count(*),course from student group by course;
data.bar(color=['red','blue','green','#123456','#abcdef'])
plt.xlabel("Course",color="red",fontdict={'fontsize':25})
plt.ylabel("Count",color="red",fontdict={'fontsize':25})
# Out:
#  * mysql://root:***@localhost/internship_batch
# 5 rows affected.
# Text(0, 0.5, 'Count')

# %%
data = %sql select name from student where id in (select sid from fees where fees>10000 )
# Out:
#  * mysql://root:***@localhost/internship_batch
# 6 rows affected.

# %%
print(data)
# Out:
# +----------+
# |   name   |
# +----------+
# | shivani  |
# |  rohan   |
# |  anisha  |
# | anushka  |
# |  devraj  |
# | priyanka |
# +----------+

# %%
data = %sql select name,course from student where id in (select sid from fees where fees>10000 )
data = data.DataFrame()
# Out:
#  * mysql://root:***@localhost/internship_batch
# 6 rows affected.

# %%
data
# Out:
#        name  course
# 0   shivani      ds
# 1     rohan      ml
# 2    anisha     aws
# 3   anushka     aws
# 4    devraj   cloud
# 5  priyanka  python

# %%
# %%sql
# select name,fees from fees inner join student on student.id = fees.sid;
# Out:
#  * mysql://root:***@localhost/internship_batch
# 6 rows affected.
# [('shivani', 12000.0),
#  ('rohan', 13000.0),
#  ('anisha', 15000.0),
#  ('anushka', 15000.0),
#  ('priyanka', 25000.0),
#  ('devraj', 22000.0)]

# %%
# %%sql
# select * from fees join student;
# Out:
#  * mysql://root:***@localhost/internship_batch
# 48 rows affected.
# [(1, 101, 12000.0, 2000.0, 10000.0, 101, 'shivani', 'ds', 'female'),
#  (2, 102, 13000.0, 1200.0, 11000.0, 101, 'shivani', 'ds', 'female'),
#  (3, 103, 15000.0, 2500.0, 9000.0, 101, 'shivani', 'ds', 'female'),
#  (4, 104, 15000.0, 1300.0, 9000.0, 101, 'shivani', 'ds', 'female'),
#  (5, 107, 25000.0, 2500.0, 19000.0, 101, 'shivani', 'ds', 'female'),
#  (6, 105, 22000.0, 6000.0, 15000.0, 101, 'shivani', 'ds', 'female'),
#  (1, 101, 12000.0, 2000.0, 10000.0, 102, 'rohan', 'ml', 'male'),
#  (2, 102, 13000.0, 1200.0, 11000.0, 102, 'rohan', 'ml', 'male'),
#  (3, 103, 15000.0, 2500.0, 9000.0, 102, 'rohan', 'ml', 'male'),
#  (4, 104, 15000.0, 1300.0, 9000.0, 102, 'rohan', 'ml', 'male'),
#  (5, 107, 25000.0, 2500.0, 19000.0, 102, 'rohan', 'ml', 'male'),
#  (6, 105, 22000.0, 6000.0, 15000.0, 102, 'rohan', 'ml', 'male'),
#  (1, 101, 12000.0, 2000.0, 10000.0, 103, 'anisha', 'aws', 'female'),
# ...

# %%
#sqlite, python file --> db
