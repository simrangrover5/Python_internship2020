# %% [markdown]
#                 Request ----> Server
#
#                 client/program <---- Data  <----- Server
#
#                 Convert byte/string format data into markup format
#
#                 Serializing --> Convert format of data from on to another

# %%
url = "https://en.wikipedia.org/wiki/Web_scraping"
import requests

# %%
data = requests.get(url)

# %%
data.status_code
# Out:
# 200

# %%
data.headers
# Out:
# {'Date': 'Tue, 07 Jul 2020 00:44:22 GMT', 'Vary': 'Accept-Encoding,Cookie,Authorization', 'Server': 'ATS/8.0.8', 'X-Content-Type-Options': 'nosniff', 'P3p': 'CP="See https://en.wikipedia.org/wiki/Special:CentralAutoLogin/P3P for more info."', 'Content-Language': 'en', 'Last-Modified': 'Sun, 05 Jul 2020 14:58:42 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Content-Encoding': 'gzip', 'Age': '44904', 'X-Cache': 'cp5008 miss, cp5011 hit/21', 'X-Cache-Status': 'hit-front', 'Server-Timing': 'cache;desc="hit-front"', 'Strict-Transport-Security': 'max-age=106384710; includeSubDomains; preload', 'Set-Cookie': 'WMF-Last-Access=07-Jul-2020;Path=/;HttpOnly;secure;Expires=Sat, 08 Aug 2020 12:00:00 GMT, WMF-Last-Access-Global=07-Jul-2020;Path=/;Domain=.wikipedia.org;HttpOnly;secure;Expires=Sat, 08 Aug 2020 12:00:00 GMT, GeoIP=IN:MH:Mumbai:19.07:72.89:v4; Path=/; secure; Domain=.wikipedia.org', 'X-Client-IP': '45.127.45.43', 'Cache-Control': 'private, s-maxage=0, max-age=0, must-revalidate', 
# ...

# %%
data.headers['Content-Length']
# Out:
# '26227'

# %%
data.text  #return string format data
# Out:
# '\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Web scraping - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"897e6831-aed7-4cbc-a8fa-7b85d185e19a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Web_scraping","wgTitle":"Web scraping","wgCurRevisionId":966176634,"wgRevisionId":966176634,"wgArticleId":2696619,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Danish-language sources (da)","CS1 French-language sources (fr)","Articles with short description","Articles needing additional references from June 2017","Al
# ...

# %%
data.content  #byte format
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Web scraping - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"897e6831-aed7-4cbc-a8fa-7b85d185e19a","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Web_scraping","wgTitle":"Web scraping","wgCurRevisionId":966176634,"wgRevisionId":966176634,"wgArticleId":2696619,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 Danish-language sources (da)","CS1 French-language sources (fr)","Articles with short description","Articles needing additional references from June 2017","A
# ...

# %%
data.text[0]
# Out:
# '\n'

# %% [markdown]
#     To convert into html format we need a tool/module bs4
#     Convert data into html
#
#     BeautifulSoup

# %%
from bs4 import BeautifulSoup

# %%
data = BeautifulSoup(data.text,'lxml')

# %%
data
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Web scraping - Wikipedia</title>
# ...

# %%
data.body
# Out:
# <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Web_scraping rootpage-Web_scraping skin-vector action-view skin-vector-legacy minerva--history-page-action-enabled">
# <div class="noprint" id="mw-page-base"></div>
# <div class="noprint" id="mw-head-base"></div>
# <div class="mw-body" id="content" role="main">
# <a id="top"></a>
# <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
# <div class="mw-indicators mw-body-content">
# </div>
# <h1 class="firstHeading" id="firstHeading" lang="en">Web scraping</h1>
# <div class="mw-body-content" id="bodyContent">
# <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
# <div id="contentSub"></div>
# <div id="jump-to-nav"></div>
# <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
# <a class="mw-jump-link" href="#searchInput">Jump to search</a>
# ...

# %%
data.head
# Out:
# <head>
# <meta charset="utf-8"/>
# <title>Web scraping - Wikipedia</title>
# ...
