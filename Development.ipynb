# %%
from PIL import Image

# %%
Image.open("req_res.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=960x540 at 0x29B2C7A8288>

# %% [markdown]
#       url --> domain --> google.com --> ip --> computer(server)

# %% [markdown]
#      req --> DNS --> Domain Name Server
#      client --> url --> www.google.com --> DNS --> return ip --> request --> ip ---> multiple routers --> server
#      server --> request(method) --> return html page --> client

# %% [markdown]
# optical fibres --> data transmit
# ISP --> Internet Service Provider --> IP Provide

# %%
# !ipconfig
# Out:
# Windows IP Configuration
#
#
# Ethernet adapter Ethernet 2:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . : www.tendawifi.com
#
# Ethernet adapter Npcap Loopback Adapter:
#
#    Connection-specific DNS Suffix  . :
#    Link-local IPv6 Address . . . . . : fe80::10f8:f6c5:c6b3:1ddf%10
#    Autoconfiguration IPv4 Address. . : 169.254.29.223
#    Subnet Mask . . . . . . . . . . . : 255.255.0.0
#    Default Gateway . . . . . . . . . :
#
# Wireless LAN adapter Local Area Connection* 1:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Wireless LAN adapter Local Area Connection* 11:
#
#    Media State . . . . . . . . . . . : Media disconnected
#    Connection-specific DNS Suffix  . :
#
# Ethernet adapter VMware Network Adapter VMnet1:
#
#    Connection-specific DNS Suffix  . :
#    Link-local IPv6 Address . . . . . : fe80::34b9:61ee:aa27:4ae6%14
# ...

# %% [markdown]
#     NAT --> Network Address Translator
#     Sender IP , Destination IP

# %% [markdown]
#     HTTP , Flask
